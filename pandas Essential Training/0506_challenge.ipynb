# %%
# my solution to challenge 05_06 from the course:
# Jonathan Fernandes - pandas Essential Training
# https://www.linkedin.com/learning/pandas-essential-training

# %%
import pandas as pd

# %%
df = pd.read_csv('olympics.csv',skiprows=4)
df
# Out:
#           City  Edition      Sport       Discipline               Athlete
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred  \
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# ### 1.
# ### Plot the number of medals achieved by the Chinese team (men and women) in Beijing 2008, using Matplotlib and Seaborn

# %%
# 
df[ (df['Edition'] == 2008) & (df['NOC']=='CHN') ]
# Out:
#           City  Edition          Sport       Discipline           Athlete
# 27176  Beijing     2008       Aquatics           Diving       ZHOU, Luxin  \
# 27177  Beijing     2008       Aquatics           Diving         WANG, Xin
# 27178  Beijing     2008       Aquatics           Diving      CHEN, Ruolin
# 27180  Beijing     2008       Aquatics           Diving          QIN, Kai
# 27181  Beijing     2008       Aquatics           Diving         HE, Chong
# ...        ...      ...            ...              ...               ...
# 29138  Beijing     2008  Weightlifting    Weightlifting        LI, Hongli
# 29140  Beijing     2008  Weightlifting    Weightlifting          LU, Yong
# 29156  Beijing     2008      Wrestling  Wrestling Free.            XU, Li
# 29171  Beijing     2008      Wrestling  Wrestling Free.        WANG, Jiao
# 29204  Beijing     2008      Wrestling  Wrestling Gre-R  CHANG, Yongxiang
#
#        NOC Gender           Event Event_gender   Medal
# ...

# %%
# selecting only Gender column
df[ (df['Edition'] == 2008) & (df['NOC']=='CHN') ]['Gender']
# Out:
# 27176      Men
# 27177    Women
# 27178    Women
# 27180      Men
# 27181      Men
#          ...
# 29138      Men
# 29140      Men
# 29156    Women
# 29171    Women
# 29204      Men
# Name: Gender, Length: 184, dtype: object

# %%
# value_counts on Gender column
df[ (df['Edition'] == 2008) & (df['NOC']=='CHN') ]['Gender'].value_counts()
# Out:
# Gender
# Women    128
# Men       56
# Name: count, dtype: int64

# %%
# simple plotting, directly from pandas
df[ (df['Edition'] == 2008) & (df['NOC']=='CHN') ]['Gender'].value_counts().plot(kind='bar');

# %%
# now with seaborn
import seaborn as sns

# %%
# selecting Edition and Country
mydata = df[ (df['Edition'] == 2008) & (df['NOC']=='CHN') ]
mydata
# Out:
#           City  Edition          Sport       Discipline           Athlete
# 27176  Beijing     2008       Aquatics           Diving       ZHOU, Luxin  \
# 27177  Beijing     2008       Aquatics           Diving         WANG, Xin
# 27178  Beijing     2008       Aquatics           Diving      CHEN, Ruolin
# 27180  Beijing     2008       Aquatics           Diving          QIN, Kai
# 27181  Beijing     2008       Aquatics           Diving         HE, Chong
# ...        ...      ...            ...              ...               ...
# 29138  Beijing     2008  Weightlifting    Weightlifting        LI, Hongli
# 29140  Beijing     2008  Weightlifting    Weightlifting          LU, Yong
# 29156  Beijing     2008      Wrestling  Wrestling Free.            XU, Li
# 29171  Beijing     2008      Wrestling  Wrestling Free.        WANG, Jiao
# 29204  Beijing     2008      Wrestling  Wrestling Gre-R  CHANG, Yongxiang
#
#        NOC Gender           Event Event_gender   Medal
# ...

# %%
# bar plot on Gender
sns.countplot(data=mydata, x='Gender', width=0.5);

# %% [markdown]
# ### 2.
# ### Plot the number of gold, silver, and bronze medals for each gender.

# %%
# just a reminder:
# mydata is China team in 2008
# we are interested in Gender and Medal columns
mydata[['Gender','Medal']]
# Out:
#       Gender   Medal
# 27176    Men  Silver
# 27177  Women  Bronze
# 27178  Women    Gold
# 27180    Men  Bronze
# 27181    Men    Gold
# ...      ...     ...
# 29138    Men  Silver
# 29140    Men    Gold
# 29156  Women  Silver
# 29171  Women    Gold
# 29204    Men  Silver
#
# [184 rows x 2 columns]

# %%
sns.countplot(data=mydata, x='Medal', hue='Gender' );

# %%
# let's order the columns and change the color (this is in fact taken from the author's solution)
sns.countplot(data=mydata, x='Medal', hue='Gender', order=['Gold','Silver','Bronze'] , palette='bwr');
