# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# x values
df = pd.DataFrame( {'x':np.arange(-2, (8*np.pi)+1, 0.1)} ) 

# y values
df['tan']= np.tan(df['x'])
df['cotan']= 1/np.tan(df['x']) # cotangens

# %%
df['tan'].describe() # we see here some outliers
# Out:
# count    282.000000
# mean      -0.531047
# std       15.745224
# min     -225.950846
# 25%       -1.007572
# 50%       -0.003982
# 75%        0.975980
# max       80.712763
# Name: tan, dtype: float64

# %%
# cropping out the outliers
my_mask =((df['tan']>10) | (df['tan']<-10))
df.loc[my_mask, 'tan'] = np.nan

# %%
# cropping out the outliers
my_mask =((df['cotan']>10) | (df['cotan']<-10))
df.loc[my_mask, 'cotan'] = np.nan

# %%
my_ticks = np.arange(0, 9*np.pi, np.pi) # x_ticks ... multiples of π 
my_ticks
# Out:
# array([ 0.        ,  3.14159265,  6.28318531,  9.42477796, 12.56637061,
#        15.70796327, 18.84955592, 21.99114858, 25.13274123])

# %%
plt.figure(figsize=(10,3)) # 
plt.plot(df.x, df.tan)
plt.title("tangens")

plt.ylim(-4, 4)
plt.xlim(-1, 26)

plt.yticks([0])
plt.xticks(my_ticks) # Set custom ticks and labels on the x-axis

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

# Remove the frame
plt.gca().spines['top'].set_visible(False)
# plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.grid(axis='x')

plt.show()

# %%
plt.figure(figsize=(10,3)) # 
plt.plot(df.x, df.cotan)
plt.title("cotangens")
plt.ylim(-4, 4)
plt.xlim(-1, 26)

plt.yticks([0])
plt.xticks(my_ticks) # Set custom ticks and labels on the x-axis

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

# Remove the frame
plt.gca().spines['top'].set_visible(False)
# plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.grid(axis='x')
plt.show()

# %%
# spolu:

# %%
plt.figure(figsize=(10,3)) # 

plt.plot(df.x, df.tan, label='tan x' , color='g')
plt.plot(df.x, df.cotan, label='cotan x' )

plt.title("tangens & cotangens")

plt.ylim(-4, 4)
plt.xlim(-1, 26)

plt.yticks([0])
plt.xticks(my_ticks) # Set custom ticks and labels on the x-axis

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

# Remove the frame
plt.gca().spines['top'].set_visible(False)
# plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.grid(axis='x')

plt.legend(bbox_to_anchor=(1.04, 0), loc="lower left") #

plt.show()
